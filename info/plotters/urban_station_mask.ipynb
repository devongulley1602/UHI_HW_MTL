# %%
from Montreal_UHI_toolbox import *
blurred_urban = gaussian_blur_xarray(urban_fraction,sigma=1.5)

# %%
fig,ax,cb = plot_field(blurred_urban,bins=[0.,0.01,.50,1.0],cmap='Greens_r',extend='neither')
plot_stations(fig,ax,field=blurred_urban,stations=dry_stations)
ax.scatter(urban_stations.lon, urban_stations.lat, transform=ccrs.PlateCarree(),
           color='red', marker='s',label='urban',s=3)
ax.scatter(suburban_stations.lon, suburban_stations.lat, transform=ccrs.PlateCarree(),
           color='orange', marker='s',label='suburban',s=3)
ax.scatter(rural_stations.lon, rural_stations.lat, transform=ccrs.PlateCarree(),
           color='blue', marker='s',label='rural',s=3)
ax.legend(title='Stations',alignment='left',framealpha=0.4)
plt.savefig('info/plots/blurred_urban.pdf')

# %%
help(plot_field)
# Out:
# Help on function plot_field in module Montreal_UHI_toolbox:
#
# plot_field(field, cmap='viridis', levels=None, vmin=None, vmax=None, cbar_label='', title='', proj=None, feature_colours='grey', extend='both', spacing='proportional', bins=None, labelsize=6)
#     Plots a 2D xarray DataArray field over a map with a discrete colorbar and regional political and lake features.
#
#     Parameters
#     ----------
#     field : xarray.DataArray
#         2D field to plot over the map domain.
#     cmap : str
#         Name of the matplotlib colormap to use.
#     vmin, vmax : float
#         Minimum and maximum values for color normalization.
#     cbar_label : str
#         Label for the colorbar.
#     title : str
#         Title to display above the map.
#     proj : cartopy.crs.Projection
#         Cartopy coordinate reference system (CRS) for the map projection.
#     feature_colours : str
#         Colour for map features such as coastlines, gridlines, and borders.
#     extend : str
# ...

# %%
fig,ax,cb = plot_field(urban_fraction,bins=[0.,0.01,.50,1.0],cmap='Greens_r',extend='neither')
plot_stations(fig,ax,field=blurred_urban,stations=dry_stations)
ax.scatter(urban_stations.lon, urban_stations.lat, transform=ccrs.PlateCarree(),
           color='red', marker='s',label=f'urban ({len(urban_stations.station.values)})',s=3)
ax.scatter(suburban_stations.lon, suburban_stations.lat, transform=ccrs.PlateCarree(),
           color='orange', marker='s',label=f'suburban ({len(suburban_stations.station.values)})',s=3)
ax.scatter(rural_stations.lon, rural_stations.lat, transform=ccrs.PlateCarree(),
           color='blue', marker='s',label=f'rural ({len(rural_stations.station.values)})',s=3)
ax.legend(title='Stations',alignment='left',framealpha=0.4)
plt.savefig('info/plots/urban_fraction.pdf')

# %%
fig,ax,cb = plot_field(urban_fraction,bins=[0.,0.01,.50,1.0],cmap='Greens_r',extend='neither')
plot_stations(fig,ax,field=blurred_urban,stations=dry_filtered_stations)
ax.scatter(urban_filtered_stations.lon, urban_filtered_stations.lat, transform=ccrs.PlateCarree(),
           color='red', marker='s',label=f'urban ({len(urban_filtered_stations.station.values)})',s=3)
ax.scatter(suburban_filtered_stations.lon, suburban_filtered_stations.lat, transform=ccrs.PlateCarree(),
           color='orange', marker='s',label=f'suburban ({len(suburban_filtered_stations.station.values)})',s=3)
ax.scatter(rural_filtered_stations.lon, rural_filtered_stations.lat, transform=ccrs.PlateCarree(),
           color='blue', marker='s',label=f'rural ({len(rural_filtered_stations.station.values)})',s=3)
ax.legend(title='Stations',alignment='left',framealpha=0.4)
plt.savefig('info/plots/urban_fraction_filtered_stations.pdf')

# %%
proj = ccrs.PlateCarree()
fig,ax,cb = plot_field(urban_fraction,bins=[0.,0.01,.50,1.0],cmap='Greens_r',extend='neither',MTL_focus=True)
plot_stations(fig,ax,field=blurred_urban,stations=dry_stations_mtl)
pos = cb.ax.get_position()
new_height = pos.height * 0.7
new_y0 = pos.y0 + (pos.height - new_height) / 2
cb.ax.set_position([
    pos.x0,
    new_y0,
    pos.width,
    new_height
])
ax.scatter(urban_stations_mtl.lon, urban_stations_mtl.lat, transform=ccrs.PlateCarree(),
           color='red', marker='s',label=f'urban ({len(urban_stations_mtl.station.values)})',s=3)
ax.scatter(suburban_stations_mtl.lon, suburban_stations_mtl.lat, transform=ccrs.PlateCarree(),
           color='orange', marker='s',label=f'suburban ({len(suburban_stations_mtl.station.values)})',s=3)
ax.scatter(rural_stations_mtl.lon, rural_stations_mtl.lat, transform=ccrs.PlateCarree(),
           color='blue', marker='s',label=f'rural ({len(rural_stations_mtl.station.values)})',s=3)
ax.legend(title='Stations',alignment='left',framealpha=0.4)
plt.savefig('info/plots/urban_fraction_mtl.pdf')
