# %%
from Montreal_UHI_toolbox import *
# from matplotlib_scalebar.scalebar import ScaleBar
# import cmasher as cmr
# import cmcrameri
# plt.style.use('seaborn-v0_8-paper')
# from pyproj import Transformer
# import matplotlib.colors as mcolors
# import matplotlib as mpl
field = veg_fields.sel(lev='21') # urban fraction
# plot_field(field)
# import numpy as np
# import cartopy.crs as ccrs
# import cartopy.feature as cfeature
# import matplotlib.pyplot as plt
# import matplotlib.ticker as mticker

# %%
def plot_field(field,cmap='viridis',levels=None,vmin=None,vmax=None,bounds=None,cbar_label='',title='',proj=None,feature_colours='grey',extend='both',spacing='proportional',bins=None,labelsize=10):
    if proj == None:
        proj = ccrs.NearsidePerspective(central_longitude=centre_lon, central_latitude=centre_lat)
        # proj = ccrs.RotatedPole(pole_longitude=106.425, pole_latitude=44.5)
        # proj = ccrs.Orthographic(central_longitude=centre_lon, central_latitude=centre_lat)
    
    fig, ax = plt.subplots(figsize=(10,10),subplot_kw={'projection': proj})
    
    # Add features from smoothed CLASS contours
    # This was selected arbitrarily until a map emerged that was regionally recognisable
    lake_features = ax.contour(lons,lats,veg_fields.sel(lev='3'),transform=ccrs.PlateCarree(),
                               levels=[0.2,1.0],#np.linspace(0.2,1.0,1),
                               colors=feature_colours,zorder=2,linewidths=[0.5])
    ax.add_feature(cfeature.BORDERS,edgecolor=feature_colours,linewidth=0.5,zorder=2)
    
    if levels is None:
        levels = 10
    if vmin is None:
        vmin = np.nanmin(field) 
    if vmax is None:
        vmax = np.nanmax(field)
    if bins == None: # Bins overrides vmin,vmax,levels if not None
        bins = np.linspace(vmin, vmax, levels + 1)
        
    # Colourbar is discrete and ranged based on vmin and vmax
    cmap = plt.get_cmap(cmap,levels)
    cbar_norm = mpl.colors.BoundaryNorm(bins, cmap.N)

    # Holds the field itself
    mesh = ax.pcolormesh(lons, lats, field, transform=ccrs.PlateCarree(),cmap=cmap,norm=cbar_norm,zorder=1)
    cb = fig.colorbar(ScalarMappable(norm=cbar_norm, cmap=cmap),ax=ax,
                      spacing=spacing,
                      orientation='vertical',
                      extend=extend,
                      shrink=0.73)
    cb.set_label(label=cbar_label,
                 rotation=0)
                 # labelpad=20)
    cb.ax.tick_params(labelsize=labelsize)
    
    if extend=='both' or extend=='max':
        cb.ax.yaxis.set_label_coords(0.5, 1.08) 
    else:
        cb.ax.yaxis.set_label_coords(0.5, 1.03) 

    # Gridline configuration
    gl = ax.gridlines(draw_labels=True, crs=ccrs.PlateCarree(), linewidth=0.5, color=feature_colours, linestyle='--')
    gl.xlocator = mticker.FixedLocator(np.arange(-180, 180, 1))  # longitude ticks
    gl.ylocator = mticker.FixedLocator(np.arange(-90, 90, 1))    # latitude ticks
    gl.top_labels = False
    gl.right_labels = False
    gl.xlabel_style = {'size': 9}
    gl.ylabel_style = {'size': 9}
    ax.axis('off')
    fig.tight_layout()

    ax.add_artist(ScaleBar(1,box_alpha=0,color=feature_colours,location='lower right'))

    plt.title(title)
    return fig,ax,cb

# %%
fig,ax,cb = plot_field(field,bins=[0.0,0.01,0.5,1.0],extend='neither',cmap='bwr',title='Urban Fraction Categorical Data Masks',cbar_label='Fraction (0-1)',feature_colours='black',labelsize=6)
# ax.scatter(stations.lon,stations.lat,color='black',marker=7,transform=ccrs.PlateCarree())
ax.scatter(urban_stations.lon,urban_stations.lat,color='black',marker=6,transform=ccrs.PlateCarree(),label='urban')
ax.scatter(neither_stations.lon,neither_stations.lat,color='black',marker='_',transform=ccrs.PlateCarree(),label= 'suburban')
ax.scatter(rural_stations.lon,rural_stations.lat,color='black',marker=7,transform=ccrs.PlateCarree(),label= 'reduced')
ax.legend(title='Stations:',framealpha=0.4,alignment='left')
plt.show()

# fig,ax = plot_field(field,bins=[0.0,0.01,0.5,1.0],extend='neither',cmap='bwr',title='Urban Fraction Data Masks',cbar_label='Fraction (0-1)',feature_colours='white')
# plt.show()
# Out:
# KeyboardInterrupt

# %%
"""
Using the lat/lon pairs given by the pavics stations (stations xarray dataset) within the domain: 
    1. Interpolate to the closest rlat/rlon grid point in the simulation
    2. Compare this point with the urban fraction field
    3. Classify station as urban or reduced urban (ie rural) with >=0.5 and <0.01 respectively
    
Using this method on the PAVICS dataset, on 2025-07-30, this gives:
    - 28 reduced-urban stations
    - 5 urban stations
"""
station_rotated_points = rotated_pole.transform_points(ccrs.PlateCarree(), stations['lon'].values, stations['lat'].values)
station_rlon = station_rotated_points[:, 0]
station_rlat = station_rotated_points[:, 1]

urban_station_mask = is_urban.sel(
    rlat=xr.DataArray(station_rlat, dims="points"),
    rlon=xr.DataArray(station_rlon, dims="points"),
    method='nearest'
).values

rural_station_mask =  is_rural.sel(
    rlat=xr.DataArray(station_rlat, dims="points"),
    rlon=xr.DataArray(station_rlon, dims="points"),
    method='nearest'
).values

stations = stations.assign_coords(is_urban=('station',urban_station_mask),is_rural=('station',rural_station_mask))
urban_stations = stations.where(stations.is_urban, drop=True)
rural_stations = stations.where(stations.is_rural, drop=True)

# %%
neither_stations = stations.where(stations.is_rural==stations.is_urban, drop=True)

# %%
stations.is_rural == stations.is_urban
# Out:
# <xarray.DataArray (station: 49)> Size: 49B
# array([False, False, False, False,  True,  True, False,  True, False,
#        False, False, False, False, False,  True,  True, False,  True,
#         True, False, False, False, False, False,  True,  True, False,
#         True, False, False, False,  True,  True,  True, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False,  True, False,  True])
# Coordinates:
#   * station       (station) object 392B '6101874' '6105460' ... '7077570'
#     stnid         (station) object 392B '6101874' '6105460' ... '7077570'
#     station_name  (station) object 392B 'CORNWALL' ... 'ST MICHEL DES SAINTS'
#     lon           (station) float64 392B -74.75 -75.18 -73.18 ... -74.55 -73.92
#     lat           (station) float64 392B 45.02 44.92 46.05 ... 45.8 46.08 46.68
#     is_urban      (station) bool 49B True False False ... False False False
#     is_rural      (station) bool 49B False True True True ... False True False

# %%
type(ccrs.PlateCarree())
# Out:
# cartopy.crs.PlateCarree

# %%
print(type(fig))
print(type(ax))
print(type(cb))
# Out:
# <class 'matplotlib.figure.Figure'>
# <class 'cartopy.mpl.geoaxes.GeoAxes'>
# <class 'matplotlib.colorbar.Colorbar'>
