# %%
from Montreal_UHI_toolbox import stations
import xarray as xr
import numpy as np

# %%
data = stations.sel(time=slice('2000','2022'))

# %%
print('Season','Station','Field','Miss Rate')
for season in ['all','JJA','SON','DJF','MAM']:
    ds = data
    if season!='all':
        ds = data.sel(time=data.time.dt.season==season)
        
    for field in ['tasmax','tasmin','tas']:
        miss_rates = []
                
        for stnid in ds.station.values:
            station = ds.sel(station=stnid)

            # Time series of tasmin, tasmax, or tas
            series = station[field].values
            
            # Percentage of NaN
            miss_rate = np.count_nonzero(np.isnan(series))/len(series)
            miss_rates.append(miss_rate)
            print(f'{season}, {station.station_name.values}, {field}, {np.round(miss_rate*100*100)/100}%')
        data = data.assign({f'{season}_miss_rates_{field}': ('station', miss_rates)})
# Out:
# Season Station Field Miss Rate
# all, CORNWALL, tasmax, 0.55%
# all, MORRISBURG, tasmax, 61.75%
# all, BERTHIERVILLE, tasmax, 100.0%
# all, DESCHAMBAULT, tasmax, 1.52%
# all, L'ASSOMPTION, tasmax, 0.86%
# all, LES CEDRES, tasmax, 5.95%
# all, OKA, tasmax, 7.65%
# all, ST ALBAN, tasmax, 3.4%
# all, STE ANNE DE LA PERADE, tasmax, 3.31%
# all, STE BEATRIX, tasmax, 12.36%
# all, ST CHARLES DE MANDEVILLE, tasmax, 3.93%
# all, ST COME, tasmax, 20.25%
# all, ST NARCISSE, tasmax, 6.33%
# all, ST TITE, tasmax, 100.0%
# all, SHAWINIGAN, tasmax, 17.71%
# all, TROIS-RIVIERES, tasmax, 1.19%
# all, BROME, tasmax, 37.57%
# all, BROMPTONVILLE, tasmax, 13.3%
# all, DRUMMONDVILLE, tasmax, 19.49%
# all, FARNHAM, tasmax, 9.7%
# all, FLEURY, tasmax, 3.3%
# all, FORTIERVILLE, tasmax, 3.81%
# all, GRANBY, tasmax, 2.44%
# all, HEMMINGFORD FOUR WINDS, tasmax, 1.71%
# all, MACDONALD COLLEGE, tasmax, 100.0%
# all, MAGOG, tasmax, 5.65%
# all, MCTAVISH, tasmax, 0.69%
# all, MONTREAL INTL A, tasmax, 0.15%
# ...

# %%
data.to_zarr('/runoff/gulley/St_Laurent/intermediates/station/stations_reliability.zarr')

# %%
data
# Out:
# <xarray.Dataset> Size: 10MB
# Dimensions:                        (station: 49, time: 8401)
# Coordinates:
#   * station                        (station) object 392B '6101874' ... '7077570'
#   * time                           (time) datetime64[ns] 67kB 2000-01-01 ... ...
#     stnid                          (station) object 392B '6101874' ... '7077570'
#     station_name                   (station) object 392B 'CORNWALL' ... 'ST M...
#     lon                            (station) float64 392B -74.75 ... -73.92
#     lat                            (station) float64 392B 45.02 44.92 ... 46.68
#     urban_fraction_blurred_std1p5  (station) float64 392B 0.3223 ... 0.04585
#     lake_fraction_blurred_std1p5   (station) float64 392B 0.1953 ... 0.1011
# Data variables: (12/27)
#     elev                           (station) float64 392B ...
#     prov                           (station) object 392B ...
#     fromyear                       (station) float64 392B ...
# ...

# %%
a = xr.open_zarr('/runoff/gulley/St_Laurent/intermediates/station/stations_reliability.zarr')
# Out:
# <xarray.Dataset> Size: 10MB
# Dimensions:                        (station: 49, time: 8401)
# Coordinates:
#     lake_fraction_blurred_std1p5   (station) float64 392B dask.array<chunksize=(49,), meta=np.ndarray>
#     lat                            (station) float64 392B dask.array<chunksize=(49,), meta=np.ndarray>
#     lon                            (station) float64 392B dask.array<chunksize=(49,), meta=np.ndarray>
#   * station                        (station) object 392B '6101874' ... '7077570'
#     station_name                   (station) object 392B dask.array<chunksize=(49,), meta=np.ndarray>
#     stnid                          (station) object 392B dask.array<chunksize=(49,), meta=np.ndarray>
#   * time                           (time) datetime64[ns] 67kB 2000-01-01 ... ...
#     urban_fraction_blurred_std1p5  (station) float64 392B dask.array<chunksize=(49,), meta=np.ndarray>
# Data variables: (12/27)
# ...
